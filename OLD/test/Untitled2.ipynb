# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def func_logit(x, L, A, C):
    return L / (1 + C * np.exp(A * x))

# %%
def linear_logit(X, A, B):
    return A * X + B

# %%
x = np.arange(0, 5)
X = np.arange(-5, 8, .01)
y = func_logit(x, 1000, -1.08, 4.302)
Y = func_logit(X, 1000, -1.08, 4.302)

# %%
#plt.scatter(x, y)
#plt.plot(X, Y)
plt.plot(X, pd.Series(Y).diff())
