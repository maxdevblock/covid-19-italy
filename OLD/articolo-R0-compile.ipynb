# %%
# BASIC ALL IN ONE

# %%bash
jupyter nbconvert articolo-R0.ipynb --to pdf --no-input --template articolo-R0.tplx
# Out:
# [NbConvertApp] Converting notebook articolo-R0.ipynb to pdf
# [NbConvertApp] Support files will be in articolo-R0_files/
# [NbConvertApp] Making directory ./articolo-R0_files
# [NbConvertApp] Making directory ./articolo-R0_files
# [NbConvertApp] Making directory ./articolo-R0_files
# [NbConvertApp] Writing 39246 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', './notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', './notebook']
# [NbConvertApp] Running xelatex 3 times: ['xelatex', './notebook.tex', '-quiet']
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 527070 bytes to articolo-R0.pdf

# %%
# SINGLE STEPS

# %%bash
jupyter nbconvert articolo-R0.ipynb --to latex --no-input --template articolo-R0.tplx
pdflatex articolo-R0.tex
bibtex articolo-R0.aux
pdflatex articolo-R0.tex
pdflatex articolo-R0.tex
pdflatex articolo-R0.tex
# Out:
# Process is terminated.

# %%
# LATEX ONLY

# %%bash
jupyter nbconvert articolo-R0.ipynb --to latex --no-input --template articolo-R0.tplx
# Out:
# [NbConvertApp] Converting notebook articolo-R0.ipynb to latex
# [NbConvertApp] Support files will be in articolo-R0_files/
# [NbConvertApp] Making directory articolo-R0_files
# [NbConvertApp] Making directory articolo-R0_files
# [NbConvertApp] Making directory articolo-R0_files
# [NbConvertApp] Writing 39246 bytes to articolo-R0.tex

# %%
# %%bash
# pdflatex articolo-R0.tex
# bibtex articolo-R0.aux
# pdflatex articolo-R0.tex
# pdflatex articolo-R0.tex
# pdflatex articolo-R0.tex
# Out:
# This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./articolo-R0.tex
# LaTeX2e <2020-02-02> patch level 5
# L3 programming layer <2020-03-06>
# (/usr/local/texlive/2020/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/local/texlive/2020/texmf-dist/tex/latex/base/size11.clo))
# (/usr/local/texlive/2020/texmf-dist/tex/latex/tcolorbox/tcolorbox.sty
# (/usr/local/texlive/2020/texmf-dist/tex/latex/pgf/basiclayer/pgf.sty
# (/usr/local/texlive/2020/texmf-dist/tex/latex/pgf/utilities/pgfrcs.sty
# (/usr/local/texlive/2020/texmf-dist/tex/generic/pgf/utilities/pgfutil-common.te
# x
# (/usr/local/texlive/2020/texmf-dist/tex/generic/pgf/utilities/pgfutil-common-li
# sts.tex))
# (/usr/local/texlive/2020/texmf-dist/tex/generic/pgf/utilities/pgfutil-latex.def
# (/usr/local/texlive/2020/texmf-dist/tex/latex/ms/everyshi.sty))
# ...
